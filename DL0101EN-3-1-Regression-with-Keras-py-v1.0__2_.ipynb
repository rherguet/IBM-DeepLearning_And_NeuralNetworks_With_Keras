# %% [markdown]
# <a href="https://cognitiveclass.ai/?utm_medium=Exinfluencer&utm_source=Exinfluencer&utm_content=000026UJ&utm_term=10006555&utm_id=NA-SkillsNetwork-Channel-SkillsNetworkCoursesIBMDeveloperSkillsNetworkDL0101ENSkillsNetwork20718188-2022-01-01"><img src = "https://s3-api.us-geo.objectstorage.softlayer.net/cf-courses-data/CognitiveClass/Logos/organization_logo/organization_logo.png" width = 400> </a>
#
# <h1 align=center><font size = 5>Regression Models with Keras</font></h1>

# %% [markdown]
# ## Introduction

# %% [markdown]
# As we discussed in the videos, despite the popularity of more powerful libraries such as PyToch and TensorFlow, they are not easy to use and have a steep learning curve. So, for people who are just starting to learn deep learning, there is no better library to use other than the Keras library.
#
# Keras is a high-level API for building deep learning models. It has gained favor for its ease of use and syntactic simplicity facilitating fast development. As you will see in this lab and the other labs in this course, building a very complex deep learning network can be achieved with Keras with only few lines of code. You will appreciate Keras even more, once you learn how to build deep models using PyTorch and TensorFlow in the other courses.
#
# So, in this lab, you will learn how to use the Keras library to build a regression model.

# %% [markdown]
# <h2>Regression Models with Keras</h2>
#
# <h3>Objective for this Notebook<h3>
# <h5> 1. How to use the Keras library to build a regression model.</h5>
# <h5> 2. Download and Clean dataset </h5>
# <h5> 3. Build a Neural Network </h5>
# <h5> 4. Train and Test the Network. </h5>

# %% [markdown]
# ## Table of Contents
#
# <div class="alert alert-block alert-info" style="margin-top: 20px">
#
# <font size = 3>
#
# 1.  <a href="https://#item31">Download and Clean Dataset</a>
# 2.  <a href="https://#item32">Import Keras</a>
# 3.  <a href="https://#item33">Build a Neural Network</a>
# 4.  <a href="https://#item34">Train and Test the Network</a>
#
# </font>
# </div>

# %% [markdown]
# <a id="item31"></a>

# %% [markdown]
# ## Download and Clean Dataset

# %% [markdown]
# Let's start by importing the <em>pandas</em> and the Numpy libraries.

# %%
# All Libraries required for this lab are listed below. The libraries pre-installed on Skills Network Labs are commented. 
# If you run this notebook on a different environment, e.g. your desktop, you may need to uncomment and install certain libraries.

#!pip install numpy==1.21.4
#!pip install pandas==1.3.4
#!pip install keras==2.1.6

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# We will be playing around with the same dataset that we used in the videos.
#
# <strong>The dataset is about the compressive strength of different samples of concrete based on the volumes of the different ingredients that were used to make them. Ingredients include:</strong>
#
# <strong>1. Cement</strong>
#
# <strong>2. Blast Furnace Slag</strong>
#
# <strong>3. Fly Ash</strong>
#
# <strong>4. Water</strong>
#
# <strong>5. Superplasticizer</strong>
#
# <strong>6. Coarse Aggregate</strong>
#
# <strong>7. Fine Aggregate</strong>

# %% [markdown]
# Let's download the data and read it into a <em>pandas</em> dataframe.

# %%
concrete_data = pd.read_csv('https://s3-api.us-geo.objectstorage.softlayer.net/cf-courses-data/CognitiveClass/DL0101EN/labs/data/concrete_data.csv')
concrete_data.head()
# Out:
#    Cement  Blast Furnace Slag  Fly Ash  Water  Superplasticizer  \
# 0   540.0                 0.0      0.0  162.0               2.5
# 1   540.0                 0.0      0.0  162.0               2.5
# 2   332.5               142.5      0.0  228.0               0.0
# 3   332.5               142.5      0.0  228.0               0.0
# 4   198.6               132.4      0.0  192.0               0.0
#
#    Coarse Aggregate  Fine Aggregate  Age  Strength
# 0            1040.0           676.0   28     79.99
# 1            1055.0           676.0   28     61.89
# 2             932.0           594.0  270     40.27
# 3             932.0           594.0  365     41.05
# 4             978.4           825.5  360     44.30

# %% [markdown]
# So the first concrete sample has 540 cubic meter of cement, 0 cubic meter of blast furnace slag, 0 cubic meter of fly ash, 162 cubic meter of water, 2.5 cubic meter of superplaticizer, 1040 cubic meter of coarse aggregate, 676 cubic meter of fine aggregate. Such a concrete mix which is 28 days old, has a compressive strength of 79.99 MPa.

# %% [markdown]
# #### Let's check how many data points we have.

# %%
concrete_data.shape
# Out:
# (1030, 9)

# %% [markdown]
# So, there are approximately 1000 samples to train our model on. Because of the few samples, we have to be careful not to overfit the training data.

# %% [markdown]
# Let's check the dataset for any missing values.

# %%
concrete_data.describe()
# Out:
#             Cement  Blast Furnace Slag      Fly Ash        Water  \
# count  1030.000000         1030.000000  1030.000000  1030.000000
# mean    281.167864           73.895825    54.188350   181.567282
# std     104.506364           86.279342    63.997004    21.354219
# min     102.000000            0.000000     0.000000   121.800000
# 25%     192.375000            0.000000     0.000000   164.900000
# 50%     272.900000           22.000000     0.000000   185.000000
# 75%     350.000000          142.950000   118.300000   192.000000
# max     540.000000          359.400000   200.100000   247.000000
#
#        Superplasticizer  Coarse Aggregate  Fine Aggregate          Age  \
# count       1030.000000       1030.000000     1030.000000  1030.000000
# mean           6.204660        972.918932      773.580485    45.662136
# std            5.973841         77.753954       80.175980    63.169912
# min            0.000000        801.000000      594.000000     1.000000
# 25%            0.000000        932.000000      730.950000     7.000000
# 50%            6.400000        968.000000      779.500000    28.000000
# 75%           10.200000       1029.400000      824.000000    56.000000
# max           32.200000       1145.000000      992.600000   365.000000
#
#           Strength
# count  1030.000000
# mean     35.817961
# std      16.705742
# min       2.330000
# 25%      23.710000
# 50%      34.445000
# 75%      46.135000
# max      82.600000

# %%
concrete_data.isnull().sum()
# Out:
# Cement                0
# Blast Furnace Slag    0
# Fly Ash               0
# Water                 0
# Superplasticizer      0
# Coarse Aggregate      0
# Fine Aggregate        0
# Age                   0
# Strength              0
# dtype: int64

# %% [markdown]
# The data looks very clean and is ready to be used to build our model.

# %% [markdown]
# #### Split data into predictors and target

# %% [markdown]
# The target variable in this problem is the concrete sample strength. Therefore, our predictors will be all the other columns.

# %%
concrete_data_columns = concrete_data.columns

predictors = concrete_data[concrete_data_columns[concrete_data_columns != 'Strength']] # all columns except Strength
target = concrete_data['Strength'] # Strength column

# %% [markdown]
# <a id="item2"></a>

# %% [markdown]
# Let's do a quick sanity check of the predictors and the target dataframes.

# %%
predictors.head()
# Out:
#    Cement  Blast Furnace Slag  Fly Ash  Water  Superplasticizer  \
# 0   540.0                 0.0      0.0  162.0               2.5
# 1   540.0                 0.0      0.0  162.0               2.5
# 2   332.5               142.5      0.0  228.0               0.0
# 3   332.5               142.5      0.0  228.0               0.0
# 4   198.6               132.4      0.0  192.0               0.0
#
#    Coarse Aggregate  Fine Aggregate  Age
# 0            1040.0           676.0   28
# 1            1055.0           676.0   28
# 2             932.0           594.0  270
# 3             932.0           594.0  365
# 4             978.4           825.5  360

# %%
target.head()
# Out:
# 0    79.99
# 1    61.89
# 2    40.27
# 3    41.05
# 4    44.30
# Name: Strength, dtype: float64

# %% [markdown]
# Finally, the last step is to normalize the data by substracting the mean and dividing by the standard deviation.

# %%
predictors_norm = (predictors - predictors.mean()) / predictors.std()
predictors_norm.head()
# Out:
#      Cement  Blast Furnace Slag   Fly Ash     Water  Superplasticizer  \
# 0  2.476712           -0.856472 -0.846733 -0.916319         -0.620147
# 1  2.476712           -0.856472 -0.846733 -0.916319         -0.620147
# 2  0.491187            0.795140 -0.846733  2.174405         -1.038638
# 3  0.491187            0.795140 -0.846733  2.174405         -1.038638
# 4 -0.790075            0.678079 -0.846733  0.488555         -1.038638
#
#    Coarse Aggregate  Fine Aggregate       Age
# 0          0.862735       -1.217079 -0.279597
# 1          1.055651       -1.217079 -0.279597
# 2         -0.526262       -2.239829  3.551340
# 3         -0.526262       -2.239829  5.055221
# 4          0.070492        0.647569  4.976069

# %% [markdown]
# Let's save the number of predictors to *n_cols* since we will need this number when building our network.

# %%
n_cols = predictors_norm.shape[1] # number of predictors

# %% [markdown]
# <a id="item1"></a>

# %% [markdown]
# <a id='item32'></a>

# %% [markdown]
# ## Import Keras

# %% [markdown]
# Recall from the videos that Keras normally runs on top of a low-level library such as TensorFlow. This means that to be able to use the Keras library, you will have to install TensorFlow first and when you import the Keras library, it will be explicitly displayed what backend was used to install the Keras library. In CC Labs, we used TensorFlow as the backend to install Keras, so it should clearly print that when we import Keras.

# %% [markdown]
# #### Let's go ahead and import the Keras library

# %%
import keras

# %% [markdown]
# As you can see, the TensorFlow backend was used to install the Keras library.

# %% [markdown]
# Let's import the rest of the packages from the Keras library that we will need to build our regressoin model.

# %%
from keras.models import Sequential
from keras.layers import Dense

# %% [markdown]
# <a id='item33'></a>

# %% [markdown]
# ## Build a Neural Network

# %% [markdown]
# Let's define a function that defines our regression model for us so that we can conveniently call it to create our model.

# %%
# define regression model
def regression_model():
    # create model
    model = Sequential()
    model.add(Dense(50, activation='relu', input_shape=(n_cols,)))
    model.add(Dense(50, activation='relu'))
    model.add(Dense(1))
    
    # compile model
    model.compile(optimizer='adam', loss='mean_squared_error')
    return model

# %% [markdown]
# The above function create a model that has two hidden layers, each of 50 hidden units.

# %% [markdown]
# <a id="item4"></a>

# %% [markdown]
# <a id='item34'></a>

# %% [markdown]
# ## Train and Test the Network

# %% [markdown]
# Let's call the function now to create our model.

# %%
# build the model
model = regression_model()

# %% [markdown]
# Next, we will train and test the model at the same time using the *fit* method. We will leave out 30% of the data for validation and we will train the model for 100 epochs.

# %%
# fit the model
model.fit(predictors_norm, target, validation_split=0.3, epochs=100, verbose=2)
# Out:
# Epoch 1/100
# 23/23 - 1s - loss: 1615.0565 - val_loss: 1100.7399 - 1s/epoch - 57ms/step
# Epoch 2/100
# 23/23 - 0s - loss: 1445.6758 - val_loss: 931.9210 - 129ms/epoch - 6ms/step
# Epoch 3/100
# 23/23 - 0s - loss: 1170.9647 - val_loss: 685.8006 - 126ms/epoch - 5ms/step
# Epoch 4/100
# 23/23 - 0s - loss: 802.3854 - val_loss: 420.3995 - 81ms/epoch - 4ms/step
# Epoch 5/100
# 23/23 - 0s - loss: 461.5168 - val_loss: 234.1720 - 61ms/epoch - 3ms/step
# Epoch 6/100
# 23/23 - 0s - loss: 287.8000 - val_loss: 172.3389 - 62ms/epoch - 3ms/step
# Epoch 7/100
# 23/23 - 0s - loss: 248.6517 - val_loss: 169.1613 - 98ms/epoch - 4ms/step
# Epoch 8/100
# 23/23 - 0s - loss: 228.4901 - val_loss: 170.1530 - 99ms/epoch - 4ms/step
# Epoch 9/100
# 23/23 - 0s - loss: 216.4086 - val_loss: 167.0359 - 65ms/epoch - 3ms/step
# Epoch 10/100
# 23/23 - 0s - loss: 206.3188 - val_loss: 164.4404 - 61ms/epoch - 3ms/step
# Epoch 11/100
# 23/23 - 0s - loss: 198.0206 - val_loss: 158.7879 - 78ms/epoch - 3ms/step
# Epoch 12/100
# 23/23 - 0s - loss: 191.8640 - val_loss: 153.5621 - 104ms/epoch - 5ms/step
# Epoch 13/100
# 23/23 - 0s - loss: 185.3382 - val_loss: 152.6348 - 69ms/epoch - 3ms/step
# Epoch 14/100
# 23/23 - 0s - loss: 179.8318 - val_loss: 148.2885 - 69ms/epoch - 3ms/step
# Epoch 15/100
# 23/23 - 0s - loss: 175.1904 - val_loss: 148.3692 - 74ms/epoch - 3ms/step
# Epoch 16/100
# 23/23 - 0s - loss: 170.7168 - val_loss: 147.6407 - 71ms/epoch - 3ms/step
# Epoch 17/100
# 23/23 - 0s - loss: 167.1374 - val_loss: 142.4324 - 99ms/epoch - 4ms/step
# Epoch 18/100
# 23/23 - 0s - loss: 163.5867 - val_loss: 140.7450 - 112ms/epoch - 5ms/step
# Epoch 19/100
# 23/23 - 0s - loss: 161.3980 - val_loss: 143.1754 - 66ms/epoch - 3ms/step
# Epoch 20/100
# 23/23 - 0s - loss: 158.7404 - val_loss: 143.0687 - 70ms/epoch - 3ms/step
# Epoch 21/100
# 23/23 - 0s - loss: 155.1642 - val_loss: 140.1499 - 61ms/epoch - 3ms/step
# Epoch 22/100
# 23/23 - 0s - loss: 152.6998 - val_loss: 139.8922 - 62ms/epoch - 3ms/step
# Epoch 23/100
# 23/23 - 0s - loss: 150.6847 - val_loss: 138.8565 - 64ms/epoch - 3ms/step
# Epoch 24/100
# 23/23 - 0s - loss: 148.6189 - val_loss: 141.7553 - 68ms/epoch - 3ms/step
# Epoch 25/100
# 23/23 - 0s - loss: 146.6009 - val_loss: 140.5847 - 72ms/epoch - 3ms/step
# Epoch 26/100
# 23/23 - 0s - loss: 144.4977 - val_loss: 139.1100 - 124ms/epoch - 5ms/step
# Epoch 27/100
# 23/23 - 0s - loss: 142.8961 - val_loss: 139.4981 - 96ms/epoch - 4ms/step
# Epoch 28/100
# 23/23 - 0s - loss: 140.4467 - val_loss: 139.3666 - 95ms/epoch - 4ms/step
# Epoch 29/100
# 23/23 - 0s - loss: 138.7890 - val_loss: 139.8518 - 89ms/epoch - 4ms/step
# Epoch 30/100
# 23/23 - 0s - loss: 137.2834 - val_loss: 138.7039 - 111ms/epoch - 5ms/step
# Epoch 31/100
# 23/23 - 0s - loss: 135.6296 - val_loss: 139.3125 - 114ms/epoch - 5ms/step
# Epoch 32/100
# 23/23 - 0s - loss: 134.4099 - val_loss: 140.6943 - 112ms/epoch - 5ms/step
# Epoch 33/100
# 23/23 - 0s - loss: 132.9503 - val_loss: 141.7097 - 114ms/epoch - 5ms/step
# Epoch 34/100
# 23/23 - 0s - loss: 130.7440 - val_loss: 139.7565 - 103ms/epoch - 4ms/step
# Epoch 35/100
# 23/23 - 0s - loss: 129.5196 - val_loss: 139.9602 - 76ms/epoch - 3ms/step
# Epoch 36/100
# 23/23 - 0s - loss: 128.2740 - val_loss: 142.3762 - 63ms/epoch - 3ms/step
# Epoch 37/100
# 23/23 - 0s - loss: 126.6868 - val_loss: 140.4179 - 72ms/epoch - 3ms/step
# Epoch 38/100
# 23/23 - 0s - loss: 125.5961 - val_loss: 141.5070 - 69ms/epoch - 3ms/step
# Epoch 39/100
# 23/23 - 0s - loss: 123.7816 - val_loss: 142.7908 - 85ms/epoch - 4ms/step
# Epoch 40/100
# 23/23 - 0s - loss: 122.5967 - val_loss: 138.1048 - 59ms/epoch - 3ms/step
# Epoch 41/100
# 23/23 - 0s - loss: 121.0488 - val_loss: 141.2936 - 63ms/epoch - 3ms/step
# Epoch 42/100
# 23/23 - 0s - loss: 119.1236 - val_loss: 140.5541 - 62ms/epoch - 3ms/step
# Epoch 43/100
# 23/23 - 0s - loss: 118.0369 - val_loss: 143.7979 - 61ms/epoch - 3ms/step
# Epoch 44/100
# 23/23 - 0s - loss: 116.6995 - val_loss: 139.6837 - 59ms/epoch - 3ms/step
# Epoch 45/100
# 23/23 - 0s - loss: 114.2135 - val_loss: 141.9253 - 60ms/epoch - 3ms/step
# Epoch 46/100
# 23/23 - 0s - loss: 112.7780 - val_loss: 139.5154 - 62ms/epoch - 3ms/step
# Epoch 47/100
# 23/23 - 0s - loss: 110.4752 - val_loss: 141.0518 - 64ms/epoch - 3ms/step
# Epoch 48/100
# 23/23 - 0s - loss: 108.7354 - val_loss: 139.9204 - 63ms/epoch - 3ms/step
# Epoch 49/100
# 23/23 - 0s - loss: 106.7360 - val_loss: 140.6056 - 63ms/epoch - 3ms/step
# Epoch 50/100
# 23/23 - 0s - loss: 105.2808 - val_loss: 143.7714 - 63ms/epoch - 3ms/step
# Epoch 51/100
# 23/23 - 0s - loss: 102.6297 - val_loss: 137.3182 - 59ms/epoch - 3ms/step
# Epoch 52/100
# 23/23 - 0s - loss: 100.9691 - val_loss: 138.1072 - 62ms/epoch - 3ms/step
# Epoch 53/100
# 23/23 - 0s - loss: 98.6775 - val_loss: 136.1499 - 64ms/epoch - 3ms/step
# Epoch 54/100
# 23/23 - 0s - loss: 96.2039 - val_loss: 136.5880 - 63ms/epoch - 3ms/step
# Epoch 55/100
# 23/23 - 0s - loss: 93.5939 - val_loss: 136.4460 - 62ms/epoch - 3ms/step
# Epoch 56/100
# 23/23 - 0s - loss: 91.4191 - val_loss: 136.1842 - 58ms/epoch - 3ms/step
# Epoch 57/100
# 23/23 - 0s - loss: 88.3633 - val_loss: 134.5941 - 62ms/epoch - 3ms/step
# Epoch 58/100
# 23/23 - 0s - loss: 87.0252 - val_loss: 133.0422 - 64ms/epoch - 3ms/step
# Epoch 59/100
# 23/23 - 0s - loss: 83.9646 - val_loss: 129.6135 - 62ms/epoch - 3ms/step
# Epoch 60/100
# 23/23 - 0s - loss: 80.4177 - val_loss: 128.1175 - 59ms/epoch - 3ms/step
# Epoch 61/100
# 23/23 - 0s - loss: 77.6594 - val_loss: 126.0859 - 61ms/epoch - 3ms/step
# Epoch 62/100
# 23/23 - 0s - loss: 75.4389 - val_loss: 122.9904 - 62ms/epoch - 3ms/step
# Epoch 63/100
# 23/23 - 0s - loss: 72.6689 - val_loss: 119.7404 - 63ms/epoch - 3ms/step
# Epoch 64/100
# 23/23 - 0s - loss: 70.6186 - val_loss: 119.5810 - 64ms/epoch - 3ms/step
# Epoch 65/100
# 23/23 - 0s - loss: 69.5457 - val_loss: 116.8378 - 64ms/epoch - 3ms/step
# Epoch 66/100
# 23/23 - 0s - loss: 65.7653 - val_loss: 117.6198 - 67ms/epoch - 3ms/step
# Epoch 67/100
# 23/23 - 0s - loss: 63.7720 - val_loss: 113.6686 - 64ms/epoch - 3ms/step
# Epoch 68/100
# 23/23 - 0s - loss: 62.2443 - val_loss: 112.0201 - 65ms/epoch - 3ms/step
# Epoch 69/100
# 23/23 - 0s - loss: 60.4096 - val_loss: 107.9001 - 60ms/epoch - 3ms/step
# Epoch 70/100
# 23/23 - 0s - loss: 58.5848 - val_loss: 110.6809 - 59ms/epoch - 3ms/step
# Epoch 71/100
# 23/23 - 0s - loss: 56.9101 - val_loss: 108.3186 - 64ms/epoch - 3ms/step
# Epoch 72/100
# 23/23 - 0s - loss: 55.9776 - val_loss: 106.1170 - 67ms/epoch - 3ms/step
# Epoch 73/100
# 23/23 - 0s - loss: 54.1510 - val_loss: 106.2621 - 66ms/epoch - 3ms/step
# Epoch 74/100
# 23/23 - 0s - loss: 53.2854 - val_loss: 106.4697 - 65ms/epoch - 3ms/step
# Epoch 75/100
# 23/23 - 0s - loss: 51.7780 - val_loss: 100.4580 - 64ms/epoch - 3ms/step
# Epoch 76/100
# 23/23 - 0s - loss: 50.8057 - val_loss: 106.5995 - 65ms/epoch - 3ms/step
# Epoch 77/100
# 23/23 - 0s - loss: 49.6733 - val_loss: 100.0811 - 62ms/epoch - 3ms/step
# Epoch 78/100
# 23/23 - 0s - loss: 49.2541 - val_loss: 108.7321 - 64ms/epoch - 3ms/step
# Epoch 79/100
# 23/23 - 0s - loss: 47.4951 - val_loss: 101.9496 - 62ms/epoch - 3ms/step
# Epoch 80/100
# 23/23 - 0s - loss: 46.9207 - val_loss: 101.5952 - 60ms/epoch - 3ms/step
# Epoch 81/100
# 23/23 - 0s - loss: 45.5179 - val_loss: 107.4539 - 58ms/epoch - 3ms/step
# Epoch 82/100
# 23/23 - 0s - loss: 45.2650 - val_loss: 103.8243 - 62ms/epoch - 3ms/step
# Epoch 83/100
# 23/23 - 0s - loss: 44.6269 - val_loss: 104.7879 - 64ms/epoch - 3ms/step
# Epoch 84/100
# 23/23 - 0s - loss: 43.3160 - val_loss: 103.8681 - 64ms/epoch - 3ms/step
# Epoch 85/100
# 23/23 - 0s - loss: 42.7365 - val_loss: 106.8308 - 60ms/epoch - 3ms/step
# Epoch 86/100
# 23/23 - 0s - loss: 42.2126 - val_loss: 116.3597 - 73ms/epoch - 3ms/step
# Epoch 87/100
# 23/23 - 0s - loss: 41.5962 - val_loss: 106.2881 - 62ms/epoch - 3ms/step
# Epoch 88/100
# 23/23 - 0s - loss: 40.6491 - val_loss: 106.1007 - 61ms/epoch - 3ms/step
# Epoch 89/100
# 23/23 - 0s - loss: 40.1565 - val_loss: 106.6632 - 62ms/epoch - 3ms/step
# Epoch 90/100
# 23/23 - 0s - loss: 39.7677 - val_loss: 99.5420 - 64ms/epoch - 3ms/step
# Epoch 91/100
# 23/23 - 0s - loss: 40.0584 - val_loss: 110.5948 - 62ms/epoch - 3ms/step
# Epoch 92/100
# 23/23 - 0s - loss: 38.4474 - val_loss: 110.0446 - 63ms/epoch - 3ms/step
# Epoch 93/100
# 23/23 - 0s - loss: 37.8851 - val_loss: 102.7990 - 64ms/epoch - 3ms/step
# Epoch 94/100
# 23/23 - 0s - loss: 37.3726 - val_loss: 110.4386 - 62ms/epoch - 3ms/step
# Epoch 95/100
# 23/23 - 0s - loss: 37.2023 - val_loss: 119.9799 - 60ms/epoch - 3ms/step
# Epoch 96/100
# 23/23 - 0s - loss: 36.3902 - val_loss: 104.9797 - 63ms/epoch - 3ms/step
# Epoch 97/100
# 23/23 - 0s - loss: 36.4356 - val_loss: 113.5331 - 75ms/epoch - 3ms/step
# Epoch 98/100
# 23/23 - 0s - loss: 35.6985 - val_loss: 126.0624 - 65ms/epoch - 3ms/step
# Epoch 99/100
# 23/23 - 0s - loss: 34.8638 - val_loss: 110.5537 - 62ms/epoch - 3ms/step
# Epoch 100/100
# 23/23 - 0s - loss: 34.4154 - val_loss: 118.2447 - 61ms/epoch - 3ms/step

# %% [markdown]
# <strong>You can refer to this [link](https://keras.io/models/sequential/?utm_medium=Exinfluencer&utm_source=Exinfluencer&utm_content=000026UJ&utm_term=10006555&utm_id=NA-SkillsNetwork-Channel-SkillsNetworkCoursesIBMDeveloperSkillsNetworkDL0101ENSkillsNetwork20718188-2022-01-01) to learn about other functions that you can use for prediction or evaluation.</strong>

# %% [markdown]
# Feel free to vary the following and note what impact each change has on the model's performance:
#
# 1.  Increase or decreate number of neurons in hidden layers
# 2.  Add more hidden layers
# 3.  Increase number of epochs

# %% [markdown]
# ### Thank you for completing this lab!
#
# This notebook was created by [Alex Aklson](https://www.linkedin.com/in/aklson/?utm_medium=Exinfluencer&utm_source=Exinfluencer&utm_content=000026UJ&utm_term=10006555&utm_id=NA-SkillsNetwork-Channel-SkillsNetworkCoursesIBMDeveloperSkillsNetworkDL0101ENSkillsNetwork20718188-2022-01-01). I hope you found this lab interesting and educational. Feel free to contact me if you have any questions!

# %% [markdown]
# ## Change Log
#
# | Date (YYYY-MM-DD) | Version | Changed By | Change Description                                          |
# | ----------------- | ------- | ---------- | ----------------------------------------------------------- |
# | 2020-09-21        | 2.0     | Srishti    | Migrated Lab to Markdown and added to course repo in GitLab |
#
# <hr>
#
# ## <h3 align="center"> © IBM Corporation 2020. All rights reserved. <h3/>

# %% [markdown]
# This notebook is part of a course on **Coursera** called *Introduction to Deep Learning & Neural Networks with Keras*. If you accessed this notebook outside the course, you can take this course online by clicking [here](https://cocl.us/DL0101EN_Coursera_Week3\_LAB1).

# %% [markdown]
# <hr>
#
# Copyright © 2019 [IBM Developer Skills Network](https://cognitiveclass.ai/?utm_medium=dswb&utm_source=bducopyrightlink&utm_content=000026UJ&utm_term=10006555&utm_id=NA-SkillsNetwork-Channel-SkillsNetworkCoursesIBMDeveloperSkillsNetworkDL0101ENSkillsNetwork20718188-2022-01-01&utm_campaign=bdu). This notebook and its source code are released under the terms of the [MIT License](https://bigdatauniversity.com/mit-license/?utm_medium=Exinfluencer&utm_source=Exinfluencer&utm_content=000026UJ&utm_term=10006555&utm_id=NA-SkillsNetwork-Channel-SkillsNetworkCoursesIBMDeveloperSkillsNetworkDL0101ENSkillsNetwork20718188-2022-01-01).
